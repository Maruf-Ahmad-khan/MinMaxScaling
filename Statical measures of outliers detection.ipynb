# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mk744\OneDrive - Poornima University\Desktop\Weekly report data\Weekly Report And Data Visualization of Affiliate Marketing\KHAN.csv")
df.head()
# Out:
#                 Campaign_Name     ID   Status       Date  Month   Amount  \
# 0               Ajio [CPS] IN   6420  pending  6/12/2024  R-Jun   426.00
# 1      TheayurvedaCo [CPS] IN  23739  pending  6/11/2024  R-Jun   429.00
# 2  Microsoft [CPS] IN US APAC  11719  pending  6/10/2024  R-Jun  8924.85
# 3  Microsoft [CPS] IN US APAC  11719  pending  6/10/2024  R-Jun  2907.37
# 4  Microsoft [CPS] IN US APAC  11719  pending  6/10/2024  R-Jun  3029.18
#
#    Payout Currency          Sub_Id Inventory  Partner              Email_Id
# 0    17.9      INR  app_searchPage    fsBlog  Admitad  agoyal@flipshope.com
# 1     0.0      INR             NaN    fsBlog  Admitad  agoyal@flipshope.com
# 2     0.0      INR          tab_ch    fsBlog  Admitad  agoyal@flipshope.com
# 3     0.0      INR            tabm    fsBlog  Admitad  agoyal@flipshope.com
# 4     0.0      INR            tabm    fsBlog  Admitad  agoyal@flipshope.com

# %%
import warnings
warnings.filterwarnings('ignore')
sns.kdeplot(df['Payout'])
# Out:
# <Axes: xlabel='Payout', ylabel='Density'>

# %%
Mean = df['Payout'].mean()
np.ceil(Mean)
# Out:
# 81.0

# %%
STD = df['Payout'].std()
np.ceil(STD)
# Out:
# 417.0

# %%
print(Mean + 3 * STD)
# Out:
# 1328.4736033880602

# %%
np.ceil(1328.4736033880602)
# Out:
# 1329.0

# %%
print(Mean - 3 * STD)
# Out:
# -1168.210940948982

# %%
np.ceil(-1168.210940948982)
# Out:
# -1168.0

# %%
data = df[(df['Payout'] > 1329.0) | (df['Payout'] < -1168.0)]

# %% [markdown]
# # Finding outliers

# %%
data[['Campaign_Name', 'Payout']][0:60]
# Out:
#                        Campaign_Name        Payout
# 452          Ancestry US CA UK AU DE   3087.280000
# 453              Pdffiller Many Geos   3337.600000
# 471              Pdffiller Many Geos   3337.600000
# 532       Economybookings Many GEO's   1671.300000
# 935                          NordVPN   3144.853600
# 979                          NordVPN   3144.853600
# 1079                          DHgate   1632.086400
# 1102  Coursera B2C Affiliate Program   1839.852000
# 1103  Coursera B2C Affiliate Program   1799.800800
# 1104  Coursera B2C Affiliate Program   1839.852000
# 1116  Coursera B2C Affiliate Program   1839.017600
# 1117  Coursera B2C Affiliate Program   1839.852000
# 1118  Coursera B2C Affiliate Program   1875.731200
# 1122  Coursera B2C Affiliate Program   1839.852000
# 1126  Coursera B2C Affiliate Program   3676.366400
# 1128  Coursera B2C Affiliate Program   1839.852000
# 1129  Coursera B2C Affiliate Program   2215.332000
# 1130  Coursera B2C Affiliate Program   1839.852000
# 1132  Coursera B2C Affiliate Program   1839.852000
# 1133  Coursera B2C Affiliate Program   1834.011200
# 1146                       Hostinger   3601.270400
# 2212                     Shopify CPA   1668.800000
# 2214                     Shopify CPA   1668.800000
# 2215                     Shopify CPA   7509.600000
# 2216                     Shopify CPA   1668.800000
# 2217                     Shopify CPA  10012.800000
# 2365                      Vrbo - CPS   1668.800000
# 3819                           Adobe   1366.813952
# 3822                           Adobe   1630.542760
# 3823                           Adobe   1375.266424
# 3824                           Adobe   1417.770760
# 3825                           Adobe   1417.770760
# 3828                           Adobe   1636.467000
# 3833                           Adobe   1825.024712
# 3834                           Adobe   1629.508104
# 3837                           Adobe   3015.621728
# 3839                           Adobe   1488.694760
# 3840                           Adobe   1630.542760
# 3843                           Adobe   6007.680000
# 3844                           Adobe   6007.680000
# 3845                           Adobe   1346.596440
# 3846                           Adobe   2446.168760
# 3847                           Adobe   5658.667168
# 3848                           Adobe   2127.010760
# 3849                           Adobe   1410.085936
# 3850                           Adobe   1993.031152
# 3851                           Adobe   6007.680000
# 3852                           Adobe   6007.680000
# 3854                           Adobe   6382.450760
# 3856                           Adobe   1557.849832
# 3858                           Adobe   6007.680000
# 4110         Goibibo Hotels [CPS] IN  11220.000000
# 4177                      ExpressVPN   3003.840000
# 4190  Coursera B2C Affiliate Program   1839.852000
# 4192  Coursera B2C Affiliate Program   1839.852000
# 4206                          DHgate   2919.565600
# 4213                          DHgate   5478.670400
# 4412  Coursera B2C Affiliate Program   1839.852000
# 4437                      ExpressVPN   3003.840000
# 4442  Coursera B2C Affiliate Program   1839.852000

# %%
data[['Campaign_Name', 'Payout']][60:120]
# Out:
#                 Campaign_Name        Payout
# 4450                  NordVPN   1859.877600
# 4481                  NordVPN   1998.388000
# 4520                  NordVPN   3114.815200
# 4557                  NordVPN   2715.137600
# 4571                  NordVPN   2715.137600
# 4641                  NordVPN   2715.137600
# 4654                    Adobe   1417.770760
# 4657                    Adobe   1344.343560
# 4658                    Adobe   2446.168760
# 4660                    Adobe   1813.017696
# 4663                    Adobe   6007.680000
# 4664            StubHub NORAM   6953.355584
# 4666                    Adobe   2740.920560
# 4668                    Adobe   1873.403224
# 4671                    Adobe   2446.168760
# 4672                    Adobe   1417.770760
# 4673                    Adobe   6007.680000
# 4674                    Adobe   5723.007752
# 4678                    Adobe   1417.770760
# 4679                    Adobe   6007.680000
# 4681                    Adobe   1967.606984
# 4682                    Adobe   2066.241408
# 6062              Shopify CPA   1668.800000
# 6278      Pdffiller Many Geos   3337.600000
# 6279  Ancestry US CA UK AU DE   1418.480000
# 7948                  NordVPN   2715.137600
# 7949                  NordVPN   3115.649600
# 8060                    Adobe   2446.168760
# 8064                    Adobe   1771.681520
# 8066                    Adobe   2446.168760
# 8067                    Adobe   1417.770760
# 8068                    Adobe   2005.138296
# 8069                    Adobe   6007.680000
# 8070                    Adobe   1344.919296
# 8071            StubHub NORAM   7291.621344
# 8072                    Adobe   1417.770760
# 8073                    Adobe   2446.168760
# 8075                    Adobe   6007.680000
# 8077                    Adobe   6007.680000
# 8078                    Adobe   2127.010760
# 8079                    Adobe   6007.680000
# 8080                    Adobe   2446.168760
# 8081                    Adobe   1472.156952
# 8082                    Adobe   6007.680000
# 8083                    Adobe   1417.770760
# 8084                    Adobe   1417.770760
# 8086                    Adobe   1873.578448
# 8087                    Adobe   2070.304936
# 8088                    Adobe   6007.680000
# 8104              Shopify CPA  10012.800000
# 8105              Shopify CPA   1668.800000
# 8118              Shopify CPA   1668.800000
# 8190              Shopify CPA   1668.800000
# 8193              Shopify CPA   1668.800000
# 8215               Vrbo - CPS   1668.800000
# 9406                    Klook   1607.054400
# 9410                    Klook   2108.528800
# 9438               Hotels.com   4034.324000
# 9451               Hotels.com   1983.368800
# 9456               Hotels.com   1917.451200

# %%
data['Payout'].sum()
# Out:
# 358143.799928

# %% [markdown]
# # Triming

# %%
Data = df[(df['Payout'] < 1329.0) & (df['Payout'] > -1168.0)]
Data[['Campaign_Name', 'Payout']]
# Out:
#                    Campaign_Name    Payout
# 0                  Ajio [CPS] IN   17.9000
# 1         TheayurvedaCo [CPS] IN    0.0000
# 2     Microsoft [CPS] IN US APAC    0.0000
# 3     Microsoft [CPS] IN US APAC    0.0000
# 4     Microsoft [CPS] IN US APAC    0.0000
# ...                          ...       ...
# 9452                  Hotels.com  159.3704
# 9453                  Hotels.com  405.5184
# 9454                  Hotels.com  333.7600
# 9455                  Hotels.com  817.7120
# 9457                  Hotels.com    0.0000
#
# [9338 rows x 2 columns]

# %%
sns.boxplot(df['Payout'])
# Out:
# <Axes: >
